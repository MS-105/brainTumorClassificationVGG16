# %% [markdown]
# the number of task we can go for before starting specailly on the image data are :
# 1. check the number of images in each class
# 2. check image size of some sample image + know the color channel also

# %%
#to know the file paths 
import os 
#for image 
from PIL import Image

# %%
base_add = "../dataset/"
dir = ("Training/", "Testing/") 
classes = os.listdir("../dataset/Testing") #train and test has same number of class so we can take any one

# %%
#to count the number of images in each label 
for t in dir:
    print("in"+t)
    for label in classes:
        temp = base_add + t + label 
        count = len(os.listdir(temp))
        print(f"{label} : {count}")
# Out:
# inTraining/
# glioma_tumor : 826
# meningioma_tumor : 822
# no_tumor : 395
# pituitary_tumor : 827
# inTesting/
# glioma_tumor : 100
# meningioma_tumor : 115
# no_tumor : 105
# pituitary_tumor : 74

# %%
Image.open("../dataset/Training/meningioma_tumor/m (100).jpg").size
img = Image.open("../dataset/Training/meningioma_tumor/m (100).jpg")
img.resize((224,224))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
#automated logic
sample_tumor = "../dataset/Training/meningioma_tumor/"
for img in os.listdir(sample_tumor)[:10]:
    temp = Image.open(sample_tumor + img)
    print(temp.show())
#image function open in systems image viewer , not reccommended
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
